# %%
rows =  c.execute('SELECT * FROM actor;')
for row in rows.fetchall():
    print(row)
# Out:
# (1, 'PRUEBA')
# (2, 'nan')
# (3, 'Lola Dueñas')
# (4, 'Melvin Van Peebles')
# (5, 'Pierre Perrier')
# (6, 'Wilson Cruz')
# (7, 'Gloria Reuben')
# (8, 'Brianne Brozey')
# (9, 'Iddo Goldberg')
# (10, 'George Wendt')
# (11, 'Eugenie Bondurant')
# (12, 'Janeane Garofalo')
# (13, 'Lauryn Hill')
# (14, 'Igor Zaripov')
# (15, 'John Savage')
# (16, 'Jennifer Rubin')
# (17, 'Bai Ling')
# (18, 'Myrna Loy')
# (19, 'Mélanie Doutey')
# (20, 'David Clennon')
# (21, 'Jenna Elfman')
# (22, 'Patrick Lyster')
# (23, 'Jack Albertson')
# (24, 'Dan Novy')
# (25, 'Jamie Kennedy')
# (26, 'Peter Fonda')
# (27, 'Kevin Peter Hall')
# (28, 'Judy Greer')
# (29, 'Olly Alexander')
# (30, 'Sue Corcoran')
# (31, 'Malcolm Goodwin')
# (32, 'Heike Makatsch')
# (33, 'Jill Hennessy')
# (34, 'Sahajak Boonthanakit')
# (35, 'Errol Flynn')
# (36, 'Matt King')
# (37, 'Sean Cameron Michael')
# (38, "Catherine O'Hara")
# (39, 'Mirlan Abdulayev')
# (40, 'Alexandra Holden')
# (41, 'Whitney Able')
# (42, 'Daniel von Bargen')
# ...
